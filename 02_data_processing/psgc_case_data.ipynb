# %% [markdown]
# # Processing Dataset using PGSC Code

# %% [markdown]
# ## Preliminaries

# %% [markdown]
# Import Dependencies

# %%
import pandas as pd
import os, re

# %% [markdown]
# Set Province

# %%
province = "Catanduanes"

# %% [markdown]
# Set Start and End Dates

# %%
start_date = pd.to_datetime('2021-01-01')
end_date = pd.to_datetime('2022-12-31')

(start_date, end_date)
# Out:
# (Timestamp('2021-01-01 00:00:00'), Timestamp('2022-12-31 00:00:00'))

# %% [markdown]
# ## Get the PSGC Codes

# %% [markdown]
# Get PSGC Code for Province

# %%
# load csv file
df_psgc_prov = pd.read_csv('../01_data/00_raw/02_psgc_codes/PH_Adm2_ProvDists.csv')

# get code for province
prov_psgc = df_psgc_prov.loc[df_psgc_prov['adm2_en'] == province].iloc[0]['adm2_psgc']
prov_psgc

# delete dataframe
del df_psgc_prov

# %% [markdown]
# Get PSGC Codes for Municipalities

# %%
# load csv file
df_psgc_mun = pd.read_csv('../01_data/00_raw/02_psgc_codes/PH_Adm3_MuniCities.csv')

# filter dataframe
df_psgc_mun = df_psgc_mun[df_psgc_mun['adm2_psgc'] == prov_psgc]

# set to length of 10 digits
#mun_pgsc = mun_pgsc.apply(lambda x: str(x).zfill(10))

df_psgc_mun['psgc_clean'] = df_psgc_mun['adm3_psgc'].apply(lambda x: str(x).zfill(10))
mun_pgsc = df_psgc_mun['psgc_clean']

mun_pgsc.values
# Out:
# array(['0502001000', '0502002000', '0502003000', '0502004000',
#        '0502005000', '0502006000', '0502007000', '0502008000',
#        '0502009000', '0502010000', '0502011000'], dtype=object)

# %%
#502001000 in mun_pgsc.values
df_psgc_mun
# Out:
#      adm1_psgc  adm2_psgc  adm3_psgc     adm3_en geo_level  len_crs
# 557  500000000  502000000  502001000   Bagamanoc       Mun    69510  \
# 558  500000000  502000000  502002000       Baras       Mun    73441
# 559  500000000  502000000  502003000        Bato       Mun    57344
# 560  500000000  502000000  502004000   Caramoran       Mun   120928
# 561  500000000  502000000  502005000     Gigmoto       Mun    80885
# 562  500000000  502000000  502006000      Pandan       Mun    72753
# 563  500000000  502000000  502007000  Panganiban       Mun    74678
# 564  500000000  502000000  502008000  San Andres       Mun    85557
# 565  500000000  502000000  502009000  San Miguel       Mun    59751
# 566  500000000  502000000  502010000        Viga       Mun    90041
# 567  500000000  502000000  502011000      Virac        Mun    60453
#
#       area_crs  len_km  area_km2  psgc_clean
# 557   68263960      69      68.0  0502001000
# 558   71126568      73      71.0  0502002000
# 559   51954499      57      51.0  0502003000
# 560  281463181     120     281.0  0502004000
# 561  106033936      80     106.0  0502005000
# 562  106047281      72     106.0  0502006000
# 563   50585420      74      50.0  0502007000
# 564  179142572      85     179.0  0502008000
# 565  242829264      59     242.0  0502009000
# 566  168222453      90     168.0  0502010000
# 567  134365217      60     134.0  0502011000

# %% [markdown]
# ## Filter Case Information by Province

# %% [markdown]
# Combine all CSV files into one DataFrame

# %%
# initialize an empty DataFrame
df_cases = pd.DataFrame()

# get all paths for each CSV file
dir = os.listdir("../01_data/00_raw/00_case_information")

# append each CSV file to DataFrame
for csv_file in dir:
    path = f'../01_data/00_raw/00_case_information/{csv_file}'

    # check if dataframe is empty
    if (df_cases.empty):
        #print(csv_file)
        df_cases = pd.read_csv(path)
    else:
        df_cases = pd.concat([df_cases, pd.read_csv(path)])
# Out:
# C:\Users\diana\AppData\Local\Temp\ipykernel_34884\2709074204.py:14: DtypeWarning: Columns (16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_cases = pd.read_csv(path)
# C:\Users\diana\AppData\Local\Temp\ipykernel_34884\2709074204.py:16: DtypeWarning: Columns (8,11,19,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_cases = pd.concat([df_cases, pd.read_csv(path)])

# %%
#verify number of cases
df_cases.shape
# Out:
# (4136488, 24)

# %%
df_cases[(df_cases['ProvRes'] == "CATANDUANES")]['psgc_clean'].unique()
# Out:
# array(['0502009000', '0502001000', '0502011000', '0502004000', None,
#        '0502005000', '0502002000', '0502007000', '0502006000',
#        '0502003000', '0502008000', '0502010000'], dtype=object)

# %% [markdown]
# Create column with cleaned PSGC

# %%
def clean_psgc(x):
    res_list = re.findall('[0-9]+', str(x))

    try:
        res = res_list[0]

        ## add zero after province
        if len(res) == 9:
            res = res[:2] + '0' + res[2:]
        elif len(res) == 10:
            res = res[:3] + '0' + res[3:]

        return res
    except IndexError:
        return None

df_cases['psgc_clean'] = df_cases['CityMuniPSGC'].apply(clean_psgc)

df_cases
# Out:
#          CaseCode   Age  AgeGroup     Sex DateSpecimen DateResultRelease
# 0         C404174  38.0  35 to 39  FEMALE          NaN        2020-01-30  \
# 1         C462688  44.0  40 to 44    MALE          NaN        2020-01-30
# 2         C387710  60.0  60 to 64  FEMALE   2020-01-23        2020-01-30
# 3         C377460  49.0  45 to 49    MALE          NaN               NaN
# 4         C498051  63.0  60 to 64    MALE   2020-03-05               NaN
# ...           ...   ...       ...     ...          ...               ...
# 136483  C27437726  55.0  55 to 59  FEMALE   12/28/2023        12/28/2023
# 136484  C86805412  35.0  35 to 39    MALE   12/28/2023        12/28/2023
# 136485   C6347838  56.0  55 to 59    MALE   12/29/2023        12/29/2023
# 136486  C80918199  65.0  65 to 69  FEMALE   12/27/2023        12/28/2023
# 136487  C16504646  65.0  65 to 69  FEMALE   12/29/2023        12/29/2023
#
#        DateRepConf    DateDied DateRecover RemovalType  ... CityMuniPSGC
# 0       2020-01-30         NaN         NaN   RECOVERED  ...  PH074610000  \
# 1       2020-02-03  2020-02-01         NaN        DIED  ...  PH074610000
# 2       2020-02-05         NaN  2020-01-31   RECOVERED  ...  PH071233000
# 3       2020-03-06         NaN         NaN   RECOVERED  ...  PH041028000
# 4       2020-03-06  2020-03-11         NaN        DIED  ...  PH045805000
# ...            ...         ...         ...         ...  ...          ...
# 136483  12/31/2023         NaN         NaN   RECOVERED  ...  PH064501000
# 136484  12/31/2023         NaN         NaN   RECOVERED  ...  PH137501000
# 136485  12/31/2023         NaN         NaN   RECOVERED  ...  PH137603000
# 136486  12/31/2023         NaN         NaN   RECOVERED  ...  PH143213000
# 136487  12/31/2023         NaN         NaN   RECOVERED  ...  PH025013000
#
#             BarangayRes BarangayPSGC HealthStatus Quarantined   DateOnset
# 0                   NaN          NaN    RECOVERED          NO  2020-01-21  \
# 1                   NaN          NaN         DIED          NO  2020-01-18
# 2                   NaN          NaN    RECOVERED          NO  2020-01-21
# 3                   NaN          NaN    RECOVERED          NO         NaN
# 4                   NaN          NaN         DIED          NO         NaN
# ...                 ...          ...          ...         ...         ...
# 136483       MANDALAGAN  PH064501050    RECOVERED         NaN  12/28/2023
# 136484     BARANGAY 168  PH137501168    RECOVERED         NaN  12/27/2023
# 136485          TUNASAN  PH137603008    RECOVERED         NaN         NaN
# 136486            DILAG  PH143213013    RECOVERED         NaN         NaN
# 136487  POBLACION NORTH  PH025013009    RECOVERED         NaN         NaN
#
#        Pregnanttab                                   ValidationStatus
# 0               NO  Removal Type is "Recovered", but no Recovered ...  \
# 1              NaN                                                NaN
# 2               NO  Case has Admitting Facility but is not Admitte...
# 3              NaN  Case has Admitting Facility but is not Admitte...
# 4              NaN  Age or Birthdate is Invalid\nCase has Lab Resu...
# ...            ...                                                ...
# 136483         NaN  Removal Type is "Recovered", but no Recovered ...
# 136484         NaN  Removal Type is "Recovered", but no Recovered ...
# 136485         NaN  Health Status is "Recovered", but no Date Reco...
# 136486         NaN  Health Status is "Recovered", but no Date Reco...
# 136487         NaN  Health Status is "Recovered", but no Date Reco...
#
#        this is just here to include the folders to git repo  psgc_clean
# 0                                                     NaN    0704610000
# 1                                                     NaN    0704610000
# 2                                                     NaN    0701233000
# 3                                                     NaN    0401028000
# 4                                                     NaN    0405805000
# ...                                                   ...           ...
# 136483                                                NaN    0604501000
# 136484                                                NaN    1307501000
# 136485                                                NaN    1307603000
# 136486                                                NaN    1403213000
# 136487                                                NaN    0205013000
#
# [4136488 rows x 25 columns]

# %% [markdown]
# Filter by PSGC

# %%
df_cases_filtered = df_cases[df_cases['psgc_clean'].isin(mun_pgsc)]

#mun_pgsc

# note: some case data don't have the psgc code so it's less than the total number of cases if using only province
df_cases_filtered.shape
# Out:
# (3999, 25)

# %% [markdown]
# Combine with Municipality Names

# %%
df_cases_filtered_with_mun = df_cases_filtered.merge(df_psgc_mun[['psgc_clean', 'adm3_en']], on='psgc_clean', how='left')

df_cases_filtered_with_mun
# Out:
#        CaseCode   Age  AgeGroup     Sex DateSpecimen DateResultRelease
# 0       C781369  50.0  50 to 54    MALE   2020-05-30               NaN  \
# 1       C636837  47.0  45 to 49    MALE          NaN               NaN
# 2       C951557   1.0    0 to 4    MALE   2020-07-02        2020-07-04
# 3       C639154  21.0  20 to 24    MALE   2020-06-30        2020-07-05
# 4       C619176  22.0  20 to 24  FEMALE   2020-07-06        2020-07-07
# ...         ...   ...       ...     ...          ...               ...
# 3994  C71566037  69.0  65 to 69    MALE   12/21/2023        12/22/2023
# 3995  C62913016  38.0  35 to 39    MALE   12/27/2023        12/28/2023
# 3996  C47629021  69.0  65 to 69  FEMALE   12/27/2023        12/28/2023
# 3997   C2258759  83.0       80+  FEMALE   12/28/2023        12/29/2023
# 3998  C52311792  73.0  70 to 74  FEMALE   12/28/2023        12/29/2023
#
#      DateRepConf DateDied DateRecover RemovalType  ...           BarangayRes
# 0     2020-06-06      NaN  2020-07-07   RECOVERED  ...                   NaN  \
# 1     2020-06-22      NaN  2020-07-08   RECOVERED  ...                   NaN
# 2     2020-07-06      NaN  2020-07-23   RECOVERED  ...                   NaN
# 3     2020-07-08      NaN         NaN   RECOVERED  ...                   NaN
# 4     2020-07-10      NaN  2020-07-23   RECOVERED  ...                   NaN
# ...          ...      ...         ...         ...  ...                   ...
# 3994  12/24/2023      NaN         NaN   RECOVERED  ...       PALTA SALVACION
# 3995  12/30/2023      NaN         NaN   RECOVERED  ...  DIVINO ROSTRO (POB.)
# 3996  12/30/2023      NaN         NaN   RECOVERED  ...                 RIZAL
# 3997  12/31/2023      NaN         NaN   RECOVERED  ...      CALATAGAN PROPER
# 3998  12/31/2023      NaN         NaN   RECOVERED  ...      CALATAGAN PROPER
#
#      BarangayPSGC HealthStatus Quarantined   DateOnset Pregnanttab
# 0             NaN    RECOVERED         YES         NaN         NaN  \
# 1             NaN    RECOVERED         YES         NaN         NaN
# 2             NaN    RECOVERED          NO  2020-06-28         NaN
# 3             NaN    RECOVERED          NO  2020-06-30         NaN
# 4             NaN    RECOVERED         YES         NaN          NO
# ...           ...          ...         ...         ...         ...
# 3994  PH052011042    RECOVERED         NaN  12/19/2023         NaN
# 3995  PH052008017    RECOVERED         NaN  12/22/2023         NaN
# 3996  PH052010018    RECOVERED         NaN  12/24/2023         NaN
# 3997  PH052011011    RECOVERED         NaN  12/26/2023         NaN
# 3998  PH052011011    RECOVERED         NaN  12/26/2023         NaN
#
#                                        ValidationStatus
# 0     Age or Birthdate is Invalid\nCase has Admittin...  \
# 1                           Age or Birthdate is Invalid
# 2                           Age or Birthdate is Invalid
# 3     Removal Type is "Recovered", but no Recovered ...
# 4                           Age or Birthdate is Invalid
# ...                                                 ...
# 3994  Removal Type is "Recovered", but no Recovered ...
# 3995  Health Status is "Recovered", but no Date Reco...
# 3996  Health Status is "Recovered", but no Date Reco...
# 3997  Removal Type is "Recovered", but no Recovered ...
# 3998  Health Status is "Recovered", but no Date Reco...
#
#      this is just here to include the folders to git repo  psgc_clean
# 0                                                   NaN    0502009000  \
# 1                                                   NaN    0502001000
# 2                                                   NaN    0502011000
# 3                                                   NaN    0502004000
# 4                                                   NaN    0502011000
# ...                                                 ...           ...
# 3994                                                NaN    0502011000
# 3995                                                NaN    0502008000
# 3996                                                NaN    0502010000
# 3997                                                NaN    0502011000
# 3998                                                NaN    0502011000
#
#          adm3_en
# 0     San Miguel
# 1      Bagamanoc
# 2         Virac
# 3      Caramoran
# 4         Virac
# ...          ...
# 3994      Virac
# 3995  San Andres
# 3996        Viga
# 3997      Virac
# 3998      Virac
#
# [3999 rows x 26 columns]

# %% [markdown]
# Only Keep Necessary Columns
