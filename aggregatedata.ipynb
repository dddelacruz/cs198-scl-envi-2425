# %% [markdown]
# # Aggregate Case Information by Date and Municiaplity

# %% [markdown]
# ## Preliminaries

# %% [markdown]
# Import dependencies

# %%
import pandas as pd
import re
import numpy as np

# %% [markdown]
# Set Province to be used

# %%
province = "CATANDUANES"

# %% [markdown]
# Read from CSV File

# %%
# read from csv file
df = pd.read_csv(f"filtered_cases/{province}_case_information.csv")
df.head()
# Out:
#    Unnamed: 0 CaseCode   Age  AgeGroup     Sex DateSpecimen DateResultRelease
# 0       19761  C781369  50.0  50 to 54    MALE   2020-05-30               NaN  \
# 1       29313  C636837  47.0  45 to 49    MALE          NaN               NaN
# 2       43311  C951557   1.0    0 to 4    MALE   2020-07-02        2020-07-04
# 3       45859  C639154  21.0  20 to 24    MALE   2020-06-30        2020-07-05
# 4       49871  C619176  22.0  20 to 24  FEMALE   2020-07-06        2020-07-07
#
#   DateRepConf DateDied DateRecover  ...      ProvRes       CityMunRes
# 0  2020-06-06      NaN  2020-07-07  ...  CATANDUANES       SAN MIGUEL  \
# 1  2020-06-22      NaN  2020-07-08  ...  CATANDUANES        BAGAMANOC
# 2  2020-07-06      NaN  2020-07-23  ...  CATANDUANES  VIRAC (CAPITAL)
# 3  2020-07-08      NaN         NaN  ...  CATANDUANES        CARAMORAN
# 4  2020-07-10      NaN  2020-07-23  ...  CATANDUANES  VIRAC (CAPITAL)
#
#   CityMuniPSGC BarangayRes BarangayPSGC HealthStatus Quarantined   DateOnset
# 0  PH052009000         NaN          NaN    RECOVERED         YES         NaN  \
# 1  PH052001000         NaN          NaN    RECOVERED         YES         NaN
# 2  PH052011000         NaN          NaN    RECOVERED          NO  2020-06-28
# 3  PH052004000         NaN          NaN    RECOVERED          NO  2020-06-30
# 4  PH052011000         NaN          NaN    RECOVERED         YES         NaN
#
#   Pregnanttab                                   ValidationStatus
# 0         NaN  Age or Birthdate is Invalid\nCase has Admittin...
# 1         NaN                        Age or Birthdate is Invalid
# 2         NaN                        Age or Birthdate is Invalid
# 3         NaN  Removal Type is "Recovered", but no Recovered ...
# 4          NO                        Age or Birthdate is Invalid
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Aggregating Data

# %% [markdown]
# ### List down columns
# - Date : date recorded
# - Municipality : municipality of case
# - NewCases : number of new cases
# - Deaths : number of deaths
# - Recoveries : number of recoveries

# %% [markdown]
# Get List of Municipalities

# %%
mun_list = df["CityMunRes"].unique()

# remove nan
mun_list = mun_list[~pd.isnull(mun_list)]

# remove parenthesis
mun_list = [re.sub(' \(.*\)', '', x) for x in mun_list]

mun_list
# Out:
# ['SAN MIGUEL',
#  'BAGAMANOC',
#  'VIRAC',
#  'CARAMORAN',
#  'GIGMOTO',
#  'BARAS',
#  'PANGANIBAN',
#  'PANDAN',
#  'BATO',
#  'SAN ANDRES',
#  'VIGA']

# %% [markdown]
# Parse Data by Municipality

# %%
# load municipality location data
locations = pd.read_csv(f"location_data/filtered_data/{province}.csv")

# set municipality name to uppercase
locations["Municipality/City"] = locations["Municipality/City"].apply(lambda x: x.upper())

locations = locations.set_index("Municipality/City")

locations
# Out:
#                    Unnamed: 0.1  Unnamed: 0     Province   Latitude
# Municipality/City
# BAGAMANOC                   401         401  Catanduanes  13.939637  \
# BARAS                       402         402  Catanduanes  13.659104
# BATO                        403         403  Catanduanes  13.608036
# CARAMORAN                   404         404  Catanduanes  13.983835
# GIGMOTO                     405         405  Catanduanes  13.778669
# PANDAN                      406         406  Catanduanes  14.049227
# PANGANIBAN                  407         407  Catanduanes  13.908167
# SAN ANDRES                  408         408  Catanduanes  13.598915
# SAN MIGUEL                  409         409  Catanduanes  13.640329
# VIGA                        410         410  Catanduanes  13.871531
# VIRAC                       411         411  Catanduanes  13.580359
#
#                     Longitude
# Municipality/City
# BAGAMANOC          124.287830
# BARAS              124.370468
# BATO               124.297787
# CARAMORAN          124.133872
# GIGMOTO            124.391173
# PANDAN             124.170211
# PANGANIBAN         124.300820
# SAN ANDRES         124.096969
# SAN MIGUEL         124.303109
# VIGA               124.308730
# VIRAC              124.231203

# %% [markdown]
# Create DataFrame for aggregated data

# %% [markdown]
# Use DateRepRem instead for consistency

# %%
df_aggregated = pd.DataFrame()
df_aggregated

for mun in mun_list:
    #print(mun)

    # for each unique dates, count the number of new cases
    cases = df.groupby("DateRepConf").size()

    # count number of deaths
    deaths = df[df["RemovalType"] == "DIED"].groupby("DateRepRem").size()

    # count number of recoveries
    recoveries = df[df["RemovalType"] == "RECOVERED"].groupby("DateRepRem").size()

    # create new DataFrame for data
    new_df = pd.DataFrame()
    new_df.index.name = "Date"

    new_df["NewCases"] = cases
    new_df["Deaths"] = deaths
    new_df["Recoveries"] = recoveries
    new_df["Municipality"] = mun
    new_df["Latitude"] = locations.loc[mun]["Latitude"]
    new_df["Longitude"] = locations.loc[mun]["Longitude"]

    new_df = new_df.fillna(0)

    # append to aggregated dataframe
    df_aggregated = pd.concat([df_aggregated, new_df], ignore_index=True)

    #mun_dict[mun] = new_df

    #print(new_df)

df_aggregated
# Out:
#       NewCases  Deaths  Recoveries Municipality   Latitude   Longitude
# 0            1     0.0         0.0   SAN MIGUEL  13.640329  124.303109
# 1            1     0.0         0.0   SAN MIGUEL  13.640329  124.303109
# 2            2     0.0         0.0   SAN MIGUEL  13.640329  124.303109
# 3            2     0.0         0.0   SAN MIGUEL  13.640329  124.303109
# 4            1     0.0         0.0   SAN MIGUEL  13.640329  124.303109
# ...        ...     ...         ...          ...        ...         ...
# 6375         2     0.0         0.0         VIGA  13.871531  124.308730
# 6376         6     0.0         0.0         VIGA  13.871531  124.308730
# 6377         1     0.0         0.0         VIGA  13.871531  124.308730
# 6378         1     0.0         6.0         VIGA  13.871531  124.308730
# 6379         3     0.0         0.0         VIGA  13.871531  124.308730
#
# [6380 rows x 6 columns]

# %% [markdown]
# Output aggregated data to CSV files

# %%
#for mun in mun_dict:
#    mun_dict[mun].to_csv(f"aggregated_data/{province}/{mun}.csv")

df_aggregated.to_csv(f"aggregated_data/{province}.csv")
